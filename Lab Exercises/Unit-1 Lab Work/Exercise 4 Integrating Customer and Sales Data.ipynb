# %%
import pandas as vAR_DSLAB_pd

vAR_DSLAB_CUSTOMER = vAR_DSLAB_pd.read_excel("C:/Users\DeepSphere.AI/Lab_Exercise/Unit-1/DSLAB_CUSTOMER_DATA.xlsx") 

vAR_DSLAB_SALES = vAR_DSLAB_pd.read_excel("C:/Users\DeepSphere.AI/Lab_Exercise/Unit-1/DSLAB_SALES_DATA.xlsx") 

vAR_DSLAB_CUSTOMER_SALES = vAR_DSLAB_CUSTOMER.merge(vAR_DSLAB_SALES)

vAR_DSLAB_CUSTOMER_SALES
# Out:
#    Customer ID     Customer Name Customer Type              Address  Country  \
# 0     CUST0001      Intersection   com.network        100 Park West      USA
# 1     CUST0001      Intersection   com.network        100 Park West      USA
# 2     CUST0001      Intersection   com.network        100 Park West      USA
# 3     CUST0001      Intersection   com.network        100 Park West      USA
# 4     CUST0002            Magnet   com.network   2500 Driveway Blvd      USA
# 5     CUST0002            Magnet   com.network   2500 Driveway Blvd      USA
# 6     CUST0003  Perspective Corp     Warehouse      121 Main Street  Belarus
# 7     CUST0004          Driveway    Enterprise  1811 Augusta Circle      USA
# 8     CUST0004          Driveway    Enterprise  1811 Augusta Circle      USA
# 9     CUST0005          IN touch    Enterprise     17 Old Post Road      USA
# 10    CUST0005          IN touch    Enterprise     17 Old Post Road      USA
# ...
